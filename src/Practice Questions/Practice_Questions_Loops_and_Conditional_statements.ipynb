# %%
Temp_c = int(input("Enter the temperature in celsius: "))
Temp_f = int(input("Enter the temperature in fahrenheit: "))

print(f"Temperature {Temp_c} in fahrenheit: {(Temp_c * 9/5) + 32} \n1Temperature {Temp_f} in celsius: {(Temp_f - 32) * 5/9}")
# Out:
# Enter the temperature in celsius: 32
# Enter the temperature in fahrenheit: 100
# Temperature 32 in fahrenheit: 89.6
# Temperature 100 in celsius: 37.77777777777778

# %%
while True:
  guess = int(input("Enter a number for guess: "))
  if guess in [1,2,3,4,5,6,7,8,9]:
    print("Well guessed!")
    break
  else:
    print("Wrong number entered.\nTry Again!")
# Out:
# Enter a number for guess: 4
# Well guessed!

# %%
for i in range(1, 51):
  if i % 3 == 0:
    print("Fizz")
  elif i % 5 == 0:
    print("Buzz")
  else:
    print("FizzBuzz")
# Out:
# FizzBuzz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# FizzBuzz
# Fizz
# Buzz
# FizzBuzz
# Fizz
# FizzBuzz
# FizzBuzz
# Fizz
# FizzBuzz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# FizzBuzz
# Fizz
# Buzz
# FizzBuzz
# Fizz
# FizzBuzz
# FizzBuzz
# Fizz
# FizzBuzz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# FizzBuzz
# Fizz
# Buzz
# FizzBuzz
# Fizz
# FizzBuzz
# FizzBuzz
# Fizz
# FizzBuzz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz

# %%
m = input("Enter the month to check its season: ").lower()
d = input("Enter the day to check its season: ").lower()

if m in ["march", "april", "may"]:
  print("Spring")
elif m in ["june", "july", "august"]:
  print("Summer")
elif m in ["september", "october", "november"]:
  print("Autumn")
else:
  print("Winter")
# Out:
# Enter the month to check its season: July
# Enter the day to check its season: 10
# Summer

# %%
a = int(input("Enter the length of side a of a triangle: "))
b = int(input("Enter the length of side b of a triangle: "))
c = int(input("Enter the length of side c of a triangle: "))

if a == b and b == c and c == a:
  print("Equilateral triangle")
elif a == b or b == c or c == a:
  print("Isosceles Triangle")
else:
  print("Scalene Triangle")
# Out:
# Enter the length of side a of a triangle: 10
# Enter the length of side b of a triangle: 10
# Enter the length of side c of a triangle: 5
# Isosceles Triangle
