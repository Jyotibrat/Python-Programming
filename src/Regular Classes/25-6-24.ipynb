# %%
t1 = ("Apple", "Orange", "Cherry", 1, 2, 3, 4, 5, 10.5, 11.5, 5, 4)
print("Current Tuple:", t1)
# Out:
# Current Tuple: ('Apple', 'Orange', 'Cherry', 1, 2, 3, 4, 5, 10.5, 11.5, 5, 4)

# %%
t2 = (1, 2, 3, 4, 5, 6, 7)
print("Size:", len(t2))
# Out:
# Size: 7

# %%
t1 = ("Apple", "Orange", "Cherry", 1, 2, 3, 4, 5, 10.5, 11.5, 5, 4)
print("Current Tuple:", t1)
print("Index 1 value:", t1[1])
print("Index between 1 to 6:", t1[1:6])
print("Last Value:", t1[-1])
print("Index up to 6:", t1[:6])
# Out:
# Current Tuple: ('Apple', 'Orange', 'Cherry', 1, 2, 3, 4, 5, 10.5, 11.5, 5, 4)
# Index 1 value: Orange
# Index between 1 to 6: ('Orange', 'Cherry', 1, 2, 3)
# Last Value: 4
# Index up to 6: ('Apple', 'Orange', 'Cherry', 1, 2, 3)

# %%
t1 = ("Apple", "Orange", "Cherry", 1, 2, 3, 4, 5, 10.5, 11.5, 5, 4)
print("Current Tuple:", t1)
x = list(t1)
print("After Convert:", x)
# Out:
# Current Tuple: ('Apple', 'Orange', 'Cherry', 1, 2, 3, 4, 5, 10.5, 11.5, 5, 4)
# After Convert: ['Apple', 'Orange', 'Cherry', 1, 2, 3, 4, 5, 10.5, 11.5, 5, 4]

# %%
t3 = tuple(("Apple", "Orange", "Cherry"))
print(t3)
# Out:
# ('Apple', 'Orange', 'Cherry')

# %%
t5 = ("Apple", "Orange", "Cherry", "Kiwi")
i = 0

while i<len(t5):
  print(t5[i])
  i = i + 1
else:
  print("loop finish")
# Out:
# Apple
# Orange
# Cherry
# Kiwi
# loop finish

# %%
from random import randint

otp = randint(10000, 99999)
print("your otp:", otp)
# Out:
# your otp: 78129

# %%
from random import shuffle

l2 = ["Apple", "Banana", "Mango"]
shuffle(l2)
print(l2)
# Out:
# ['Apple', 'Mango', 'Banana']
