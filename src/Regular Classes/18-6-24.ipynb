# %%
list_1 = [1, 2, 3, 4, 5]
extra = list_1[0]
list_1[0] = list_1[-1]
list_1[-1] = extra
print(list_1)
# Out:
# [5, 2, 3, 4, 1]

# %%
list_1 = [1, 2, 3, 4, 5]
n_1 = input("Enter the index you want to swap: ")
n_2 = input("Enter the index you want to swap: ")
extra = list_1[int(n_1)]
list_1[int(n_1)] = list_1[int(n_2)]
list_1[int(n_2)] = extra
print(list_1)
# Out:
# Enter the index you want to swap: 0
# Enter the index you want to swap: 4
# [5, 2, 3, 4, 1]

# %%
list_1 = [1, 2, 3, 4, 5]
print(len(list_1))
# Out:
# 5

# %%
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
if n1 > n2:
  print("First number is maximum.")
else:
  print("Second number is maximum.")
# Out:
# Enter first number: 1
# Enter second number: 2
# Second number is maximum.

# %%
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
if n1 > n2:
  print("Second number is minimum.")
else:
  print("First number is minimum.")
# Out:
# Enter first number: 10
# Enter second number: 20
# First number is minimum.
